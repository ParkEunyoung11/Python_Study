# %%
import os
import shutil
 
original_dataset_dir = './dataset'   
classes_list = os.listdir(original_dataset_dir) 
 
base_dir = './splitted' 
os.mkdir(base_dir)
 
train_dir = os.path.join(base_dir, 'train') 
os.mkdir(train_dir)
validation_dir = os.path.join(base_dir, 'val')
os.mkdir(validation_dir)
test_dir = os.path.join(base_dir, 'test')
os.mkdir(test_dir)

for cls in classes_list[0:4]:     
    os.mkdir(os.path.join(train_dir, cls))
    os.mkdir(os.path.join(validation_dir, cls))
    os.mkdir(os.path.join(test_dir, cls))

# %%
import math
 
for cls in classes_list[0:4]:
    path = os.path.join(original_dataset_dir, cls)
    fnames = os.listdir(path)
 
    train_size = math.floor(len(fnames) * 0.6)
    validation_size = math.floor(len(fnames) * 0.2)
    test_size = math.floor(len(fnames) * 0.2)
    
    train_fnames = fnames[:train_size]
    print("Train size(",cls,"): ", len(train_fnames))
    for fname in train_fnames:
        src = os.path.join(path, fname)
        dst = os.path.join(os.path.join(train_dir, cls), fname)
        shutil.copyfile(src, dst)
        
    validation_fnames = fnames[train_size:(validation_size + train_size)]
    print("Validation size(",cls,"): ", len(validation_fnames))
    for fname in validation_fnames:
        src = os.path.join(path, fname)
        dst = os.path.join(os.path.join(validation_dir, cls), fname)
        shutil.copyfile(src, dst)
        
    test_fnames = fnames[(train_size+validation_size):(validation_size + train_size +test_size)]

    print("Test size(",cls,"): ", len(test_fnames))
    for fname in test_fnames:
        src = os.path.join(path, fname)
        dst = os.path.join(os.path.join(test_dir, cls), fname)
        shutil.copyfile(src, dst)
# Out:
# Train size( Apple___Apple_scab ):  378
# Validation size( Apple___Apple_scab ):  126
# Test size( Apple___Apple_scab ):  126
# Train size( Apple___Black_rot ):  372
# Validation size( Apple___Black_rot ):  124
# Test size( Apple___Black_rot ):  124
# Train size( Apple___Cedar_apple_rust ):  165
# Validation size( Apple___Cedar_apple_rust ):  55
# Test size( Apple___Cedar_apple_rust ):  55
# Train size( Apple___healthy ):  987
# Validation size( Apple___healthy ):  329
# Test size( Apple___healthy ):  329

# %%
import matplotlib.pyplot as plt

# %%
import torch
import os
 
USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda" if USE_CUDA else "cpu")
BATCH_SIZE = 256 
EPOCH = 30

# %%
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder 
 
transform_base = transforms.Compose([transforms.Resize((64,64)), transforms.ToTensor()]) 
train_dataset = ImageFolder(root='./splitted/train', transform=transform_base) 
val_dataset = ImageFolder(root='./splitted/val', transform=transform_base)

# %%
from torch.utils.data import DataLoader

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=4)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=4)

# %%
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
 
class Net(nn.Module): 
  
    def __init__(self): 
    
        super(Net, self).__init__() 

        self.conv1 = nn.Conv2d(3, 32, 3, padding=1) 
        self.pool = nn.MaxPool2d(2,2)  
        self.conv2 = nn.Conv2d(32, 64, 3, padding=1)  
        self.conv3 = nn.Conv2d(64, 64, 3, padding=1)  

        self.fc1 = nn.Linear(4096, 512) 
        self.fc2 = nn.Linear(512, 33) 
    
    def forward(self, x):  
    
        x = self.conv1(x)
        x = F.relu(x)  
        x = self.pool(x) 
        x = F.dropout(x, p=0.25, training=self.training) 

        x = self.conv2(x)
        x = F.relu(x) 
        x = self.pool(x) 
        x = F.dropout(x, p=0.25, training=self.training)

        x = self.conv3(x) 
        x = F.relu(x) 
        x = self.pool(x) 
        x = F.dropout(x, p=0.25, training=self.training)

        x = x.view(-1, 4096)  
        x = self.fc1(x) 
        x = F.relu(x) 
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.fc2(x) 

        return F.log_softmax(x, dim=1)  
        

model_base = Net().to(DEVICE)  
optimizer = optim.Adam(model_base.parameters(), lr=0.001)

# %%
def train(model, train_loader, optimizer):
    model.train()  
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(DEVICE), target.to(DEVICE) 
        optimizer.zero_grad() 
        output = model(data)  
        loss = F.cross_entropy(output, target) 
        loss.backward()  
        optimizer.step()

# %%
def predict():
    data, target = next(iter(val_loader))
    outputs= model_base(data)
    _, predicted = torch.max(outputs, 1)
    return predicted, target

# %%
def evaluate(model, test_loader):
    model.eval()  
    test_loss = 0 
    correct = 0   
    
    with torch.no_grad(): 
        for data, target in test_loader:
            data, target = data.to(DEVICE), target.to(DEVICE)  
            output = model(data) 
            
            test_loss += F.cross_entropy(output,target, reduction='sum').item() 
 
            pred = output.max(1, keepdim=True)[1]
            correct += pred.eq(target.view_as(pred)).sum().item() 
   
    test_loss /= len(test_loader.dataset) 
    test_accuracy = 100. * correct / len(test_loader.dataset) 
    return test_loss, test_accuracy

# %%
predicted_result, target = predict()

# %%
for i in range(len(predicted_result)):
    print("{}:predicted={}, target={}".format(i, predicted_result[i], target[i]))
# Out:
# 0:predicted=25, target=3
# 1:predicted=25, target=3
# 2:predicted=8, target=3
# 3:predicted=20, target=1
# 4:predicted=0, target=3
# 5:predicted=8, target=2
# 6:predicted=28, target=0
# 7:predicted=25, target=1
# 8:predicted=0, target=0
# 9:predicted=0, target=2
# 10:predicted=25, target=1
# 11:predicted=25, target=1
# 12:predicted=13, target=3
# 13:predicted=13, target=1
# 14:predicted=0, target=1
# 15:predicted=13, target=3
# 16:predicted=0, target=0
# 17:predicted=23, target=3
# 18:predicted=8, target=3
# 19:predicted=28, target=1
# 20:predicted=0, target=3
# 21:predicted=25, target=1
# 22:predicted=13, target=0
# 23:predicted=13, target=2
# 24:predicted=19, target=3
# 25:predicted=13, target=0
# 26:predicted=0, target=3
# 27:predicted=8, target=1
# 28:predicted=8, target=3
# 29:predicted=28, target=0
# 30:predicted=25, target=0
# 31:predicted=20, target=1
# 32:predicted=28, target=0
# 33:predicted=0, target=3
# 34:predicted=8, target=3
# 35:predicted=13, target=3
# 36:predicted=16, target=3
# 37:predicted=4, target=2
# 38:predicted=25, target=3
# 39:predicted=8, target=0
# 40:predicted=28, target=0
# 41:predicted=13, target=3
# 42:predicted=8, target=1
# 43:predicted=4, target=0
# 44:predicted=13, target=3
# 45:predicted=0, target=3
# 46:predicted=13, target=2
# 47:predicted=25, target=3
# 48:predicted=25, target=1
# 49:predicted=17, target=3
# 50:predicted=8, target=2
# 51:predicted=13, target=3
# 52:predicted=8, target=1
# 53:predicted=28, target=3
# 54:predicted=0, target=3
# 55:predicted=25, target=3
# 56:predicted=0, target=3
# 57:predicted=28, target=0
# 58:predicted=25, target=3
# 59:predicted=13, target=3
# 60:predicted=28, target=0
# 61:predicted=25, target=0
# 62:predicted=27, target=3
# 63:predicted=0, target=3
# 64:predicted=0, target=0
# 65:predicted=26, target=3
# 66:predicted=13, target=3
# 67:predicted=0, target=2
# 68:predicted=25, target=0
# 69:predicted=0, target=1
# 70:predicted=28, target=1
# 71:predicted=28, target=3
# 72:predicted=0, target=1
# 73:predicted=8, target=1
# 74:predicted=28, target=3
# 75:predicted=25, target=0
# 76:predicted=23, target=1
# 77:predicted=25, target=3
# 78:predicted=26, target=2
# 79:predicted=0, target=3
# 80:predicted=13, target=1
# 81:predicted=28, target=3
# 82:predicted=25, target=3
# 83:predicted=28, target=3
# 84:predicted=8, target=0
# 85:predicted=13, target=3
# 86:predicted=13, target=3
# 87:predicted=13, target=3
# 88:predicted=17, target=3
# 89:predicted=28, target=3
# 90:predicted=0, target=3
# 91:predicted=9, target=1
# 92:predicted=13, target=1
# 93:predicted=0, target=1
# 94:predicted=13, target=1
# 95:predicted=0, target=3
# 96:predicted=8, target=3
# 97:predicted=18, target=3
# 98:predicted=13, target=3
# 99:predicted=8, target=2
# 100:predicted=25, target=3
# 101:predicted=4, target=1
# 102:predicted=13, target=1
# 103:predicted=13, target=3
# 104:predicted=25, target=1
# 105:predicted=0, target=1
# 106:predicted=29, target=3
# 107:predicted=25, target=3
# 108:predicted=13, target=2
# 109:predicted=0, target=1
# 110:predicted=4, target=1
# 111:predicted=4, target=0
# 112:predicted=13, target=1
# 113:predicted=0, target=1
# 114:predicted=0, target=1
# 115:predicted=17, target=0
# 116:predicted=13, target=3
# 117:predicted=0, target=3
# 118:predicted=13, target=3
# 119:predicted=8, target=0
# 120:predicted=13, target=3
# 121:predicted=25, target=0
# 122:predicted=0, target=3
# 123:predicted=28, target=3
# 124:predicted=0, target=3
# 125:predicted=0, target=3
# 126:predicted=28, target=0
# 127:predicted=8, target=3
# 128:predicted=13, target=3
# 129:predicted=13, target=1
# 130:predicted=13, target=3
# 131:predicted=13, target=1
# 132:predicted=28, target=1
# 133:predicted=13, target=2
# 134:predicted=20, target=3
# 135:predicted=0, target=0
# 136:predicted=23, target=1
# 137:predicted=8, target=0
# 138:predicted=28, target=3
# 139:predicted=13, target=3
# 140:predicted=29, target=0
# 141:predicted=25, target=3
# 142:predicted=18, target=3
# 143:predicted=0, target=3
# 144:predicted=0, target=3
# 145:predicted=0, target=3
# 146:predicted=16, target=1
# 147:predicted=0, target=2
# 148:predicted=16, target=2
# 149:predicted=4, target=3
# 150:predicted=8, target=3
# 151:predicted=25, target=3
# 152:predicted=0, target=3
# 153:predicted=28, target=3
# 154:predicted=25, target=1
# 155:predicted=8, target=3
# 156:predicted=8, target=3
# 157:predicted=13, target=3
# 158:predicted=25, target=3
# 159:predicted=17, target=0
# 160:predicted=25, target=3
# 161:predicted=8, target=3
# 162:predicted=13, target=3
# 163:predicted=8, target=3
# 164:predicted=13, target=3
# 165:predicted=13, target=1
# 166:predicted=28, target=3
# 167:predicted=13, target=3
# 168:predicted=28, target=3
# 169:predicted=13, target=2
# 170:predicted=13, target=3
# 171:predicted=25, target=3
# 172:predicted=13, target=1
# 173:predicted=28, target=1
# 174:predicted=13, target=3
# 175:predicted=0, target=3
# 176:predicted=28, target=3
# 177:predicted=13, target=3
# 178:predicted=8, target=0
# 179:predicted=13, target=3
# 180:predicted=13, target=3
# 181:predicted=8, target=3
# 182:predicted=25, target=3
# 183:predicted=28, target=1
# 184:predicted=25, target=3
# 185:predicted=0, target=1
# 186:predicted=13, target=3
# 187:predicted=28, target=0
# 188:predicted=13, target=1
# 189:predicted=0, target=3
# 190:predicted=8, target=3
# 191:predicted=0, target=3
# 192:predicted=0, target=2
# 193:predicted=13, target=1
# 194:predicted=0, target=3
# 195:predicted=28, target=0
# 196:predicted=13, target=3
# 197:predicted=13, target=0
# 198:predicted=15, target=1
# 199:predicted=13, target=2
# 200:predicted=0, target=3
# 201:predicted=0, target=3
# 202:predicted=13, target=2
# 203:predicted=25, target=1
# 204:predicted=25, target=3
# 205:predicted=13, target=1
# 206:predicted=28, target=0
# 207:predicted=0, target=0
# 208:predicted=25, target=0
# 209:predicted=28, target=3
# 210:predicted=28, target=3
# 211:predicted=23, target=3
# 212:predicted=0, target=0
# 213:predicted=25, target=1
# 214:predicted=13, target=3
# 215:predicted=28, target=3
# 216:predicted=0, target=3
# 217:predicted=13, target=3
# 218:predicted=0, target=1
# 219:predicted=28, target=2
# 220:predicted=13, target=3
# 221:predicted=8, target=2
# 222:predicted=0, target=3
# 223:predicted=25, target=3
# 224:predicted=8, target=1
# 225:predicted=13, target=2
# 226:predicted=13, target=3
# 227:predicted=28, target=3
# 228:predicted=0, target=1
# 229:predicted=25, target=2
# 230:predicted=13, target=1
# 231:predicted=28, target=3
# 232:predicted=0, target=0
# 233:predicted=13, target=3
# 234:predicted=19, target=0
# 235:predicted=25, target=3
# 236:predicted=0, target=1
# 237:predicted=28, target=3
# 238:predicted=13, target=3
# 239:predicted=0, target=1
# 240:predicted=21, target=0
# 241:predicted=28, target=3
# 242:predicted=13, target=2
# 243:predicted=0, target=3
# 244:predicted=0, target=3
# 245:predicted=17, target=1
# 246:predicted=25, target=3
# 247:predicted=28, target=1
# 248:predicted=8, target=3
# 249:predicted=0, target=3
# 250:predicted=13, target=3
# 251:predicted=13, target=1
# 252:predicted=28, target=3
# 253:predicted=8, target=0
# 254:predicted=0, target=3
# 255:predicted=13, target=2

# %%
import time
import copy
 
def train_baseline(model ,train_loader, val_loader, optimizer, num_epochs = 30):
    best_acc = 0.0  
    best_model_wts = copy.deepcopy(model.state_dict()) 
 
    for epoch in range(1, num_epochs + 1):
        since = time.time()  
        train(model, train_loader, optimizer)
        train_loss, train_acc = evaluate(model, train_loader) 
        val_loss, val_acc = evaluate(model, val_loader)
        
        if val_acc > best_acc: 
            best_acc = val_acc 
            best_model_wts = copy.deepcopy(model.state_dict())
        
        time_elapsed = time.time() - since
        print('-------------- epoch {} ----------------'.format(epoch))
        print('train Loss: {:.4f}, Accuracy: {:.2f}%'.format(train_loss, train_acc))   
        print('val Loss: {:.4f}, Accuracy: {:.2f}%'.format(val_loss, val_acc))
        print('Completed in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60)) 
    model.load_state_dict(best_model_wts)  
    return model
 

base = train_baseline(model_base, train_loader, val_loader, optimizer, EPOCH)  	 #(16)
torch.save(base,'baseline.pt')
# Out:
# -------------- epoch 1 ----------------
# train Loss: 0.2779, Accuracy: 88.54%
# val Loss: 0.3762, Accuracy: 85.96%
# Completed in 0m 34s
# -------------- epoch 2 ----------------
# train Loss: 0.1239, Accuracy: 96.16%
# val Loss: 0.2103, Accuracy: 93.06%
# Completed in 0m 34s
# -------------- epoch 3 ----------------
# train Loss: 0.1189, Accuracy: 96.48%
# val Loss: 0.2115, Accuracy: 92.59%
# Completed in 0m 30s
# -------------- epoch 4 ----------------
# train Loss: 0.1883, Accuracy: 92.80%
# val Loss: 0.2659, Accuracy: 91.48%
# Completed in 0m 30s
# -------------- epoch 5 ----------------
# train Loss: 0.1654, Accuracy: 94.79%
# val Loss: 0.2586, Accuracy: 92.59%
# Completed in 0m 30s
# -------------- epoch 6 ----------------
# train Loss: 0.1319, Accuracy: 95.79%
# val Loss: 0.2257, Accuracy: 93.06%
# Completed in 0m 31s
# -------------- epoch 7 ----------------
# train Loss: 0.1243, Accuracy: 96.16%
# val Loss: 0.2169, Accuracy: 92.43%
# Completed in 0m 30s
# -------------- epoch 8 ----------------
# train Loss: 0.1105, Accuracy: 96.42%
# val Loss: 0.2238, Accuracy: 91.96%
# Completed in 0m 30s
# -------------- epoch 9 ----------------
# train Loss: 0.0884, Accuracy: 97.37%
# val Loss: 0.2009, Accuracy: 93.06%
# Completed in 0m 30s
# -------------- epoch 10 ----------------
# train Loss: 0.0704, Accuracy: 97.79%
# val Loss: 0.1667, Accuracy: 95.11%
# Completed in 0m 30s
# -------------- epoch 11 ----------------
# train Loss: 0.0784, Accuracy: 97.27%
# val Loss: 0.1890, Accuracy: 94.64%
# Completed in 0m 31s
# -------------- epoch 12 ----------------
# train Loss: 0.0703, Accuracy: 98.00%
# val Loss: 0.1812, Accuracy: 94.01%
# Completed in 0m 39s
# -------------- epoch 13 ----------------
# train Loss: 0.0806, Accuracy: 97.79%
# val Loss: 0.1930, Accuracy: 93.85%
# Completed in 0m 35s
# -------------- epoch 14 ----------------
# train Loss: 0.0771, Accuracy: 97.53%
# val Loss: 0.1934, Accuracy: 94.16%
# Completed in 0m 36s
# -------------- epoch 15 ----------------
# train Loss: 0.0626, Accuracy: 98.16%
# val Loss: 0.1673, Accuracy: 95.27%
# Completed in 0m 34s
# -------------- epoch 16 ----------------
# train Loss: 0.0767, Accuracy: 97.37%
# val Loss: 0.2016, Accuracy: 92.74%
# Completed in 0m 37s
# -------------- epoch 17 ----------------
# train Loss: 0.0420, Accuracy: 98.95%
# val Loss: 0.1440, Accuracy: 95.27%
# Completed in 0m 32s
# -------------- epoch 18 ----------------
# train Loss: 0.0338, Accuracy: 98.95%
# val Loss: 0.1562, Accuracy: 95.58%
# Completed in 0m 31s
# -------------- epoch 19 ----------------
# train Loss: 0.0390, Accuracy: 98.79%
# val Loss: 0.1558, Accuracy: 95.58%
# Completed in 0m 31s
# -------------- epoch 20 ----------------
# train Loss: 0.0544, Accuracy: 98.48%
# val Loss: 0.1828, Accuracy: 93.85%
# Completed in 0m 33s
# -------------- epoch 21 ----------------
# train Loss: 0.0386, Accuracy: 99.11%
# val Loss: 0.1527, Accuracy: 95.27%
# Completed in 0m 33s
# -------------- epoch 22 ----------------
# train Loss: 0.0382, Accuracy: 99.00%
# val Loss: 0.1533, Accuracy: 95.43%
# Completed in 0m 31s
# -------------- epoch 23 ----------------
# train Loss: 0.0299, Accuracy: 99.16%
# val Loss: 0.1639, Accuracy: 95.58%
# Completed in 0m 30s
# -------------- epoch 24 ----------------
# train Loss: 0.0461, Accuracy: 98.58%
# val Loss: 0.1760, Accuracy: 94.16%
# Completed in 0m 30s
# -------------- epoch 25 ----------------
# train Loss: 0.0486, Accuracy: 98.37%
# val Loss: 0.1850, Accuracy: 95.11%
# Completed in 0m 30s
# -------------- epoch 26 ----------------
# train Loss: 0.0272, Accuracy: 99.37%
# val Loss: 0.1503, Accuracy: 95.90%
# Completed in 0m 34s
# -------------- epoch 27 ----------------
# train Loss: 0.0242, Accuracy: 99.47%
# val Loss: 0.1446, Accuracy: 95.74%
# Completed in 0m 33s
# -------------- epoch 28 ----------------
# train Loss: 0.0313, Accuracy: 98.84%
# val Loss: 0.1550, Accuracy: 95.11%
# Completed in 0m 31s
# -------------- epoch 29 ----------------
# train Loss: 0.0383, Accuracy: 98.84%
# val Loss: 0.1799, Accuracy: 95.58%
# Completed in 0m 31s
# -------------- epoch 30 ----------------
# train Loss: 0.0510, Accuracy: 98.32%
# val Loss: 0.2203, Accuracy: 93.85%
# Completed in 0m 34s
